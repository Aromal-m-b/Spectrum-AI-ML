# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Dataset/data.csv')

# %%
df.head()
# Out:
#       ad_archive_id           advertiser         category ad_type  \
# 0  1004779182125046            The Code   developer_tools    feed
# 1  1007743538605223           Cloudflare  developer_tools    feed
# 2  1026799126350986  EaseSourcing Global  developer_tools    feed
# 3  1029875425240317  Datadog Cheatsheets  developer_tools    feed
# 4  1042946695146312            Coralogix  developer_tools    feed
#
#     image_type has_text  days_active human_headline_score human_image_score  \
# 0  designed-ad     True         37.0                  NaN               bad
# 1  designed-ad     True         58.0                  NaN              good
# 2  designed-ad     True         20.0                  NaN               bad
# 3  designed-ad     True        411.0                  NaN               bad
# 4  designed-ad     True         17.0                  NaN              fair
#
#   human_fit_score ai_headline_score ai_image_score ai_fit_score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ad_archive_id         500 non-null    int64
#  1   advertiser            500 non-null    str
#  2   category              500 non-null    str
#  3   ad_type               500 non-null    str
#  4   image_type            485 non-null    str
#  5   has_text              439 non-null    object
#  6   days_active           495 non-null    float64
#  7   human_headline_score  29 non-null     str
#  8   human_image_score     500 non-null    str
#  9   human_fit_score       29 non-null     str
#  10  ai_headline_score     500 non-null    str
#  11  ai_image_score        500 non-null    str
#  12  ai_fit_score          500 non-null    str
#  13  ai_reasoning          500 non-null    str
#  14  ai_model              500 non-null    str
#  15  collected_at          500 non-null    str
# ...
