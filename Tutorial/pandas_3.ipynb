# %% [raw]
# the column name farm_id contains only unique values
# the column named sensor_id contains only unique values
# These two columns doesnt contrinute anthing for finding a relation in the dataset
#
# in column crop disease some has null values
# looking for the circumstances that a crop can have disease ,
# based on the data given the type of the crop doesnt show any influence in affecting its stage of the diesease
#
# so lets look for the fertilizer applied to it , the lack of fertilizers or medicine to the crop had made the crop severe in disease, since no crop will be initially has a severe disease
# so the crop had the disease to severe because of lack of nutrients and medicine, while others who got proper medicine and nutrients survided,
#
# in this case there is also a set that gone undocumented which is the crops which never had any disease to begin with we also need to find them

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../Dataset/dataset_final.csv")
df.head()
# Out:
#     farm_id     region_x crop_type  soil_moisture_%  soil_pH  temperature_C  \
# 0  FARM0001  North India     Wheat            35.95     5.99          17.79
# 1  FARM0002    South USA   Soybean            19.74     7.24          30.18
# 2  FARM0003    South USA     Wheat            29.32     7.16          27.37
# 3  FARM0004  Central USA     Maize            17.33     6.03          33.73
# 4  FARM0005  Central USA    Cotton            19.37     5.92          33.86
#
#    rainfall_mm  humidity_%  sunlight_hours irrigation_type  ...   timestamp  \
# 0        75.62       77.03            7.27             NaN  ...  2024-03-19
# 1        89.91       61.13            5.67       Sprinkler  ...  2024-04-21
# 2       265.43       68.87            8.23            Drip  ...  2024-02-28
# 3       212.01       70.46            5.03       Sprinkler  ...  2024-05-14
# 4       269.09       55.73            7.93             NaN  ...  2024-04-13
#
# ...

# %%
df.describe()
# Out:
#        soil_moisture_%     soil_pH  temperature_C  rainfall_mm  humidity_%  \
# count       500.000000  500.000000     500.000000   500.000000  500.000000
# mean         26.750140    6.523980      24.675740   181.685740   65.194460
# std          10.150053    0.585558       5.348899    72.293091   14.642849
# min          10.160000    5.510000      15.000000    50.170000   40.230000
# 25%          17.890000    6.030000      20.295000   119.217500   51.865000
# 50%          25.855000    6.530000      24.655000   191.545000   65.685000
# 75%          36.022500    7.040000      29.090000   239.035000   77.995000
# max          44.980000    7.500000      34.840000   298.960000   90.000000
#
#        sunlight_hours  pesticide_usage_ml  total_days  yield_kg_per_hectare  \
# count       500.00000          500.000000  500.000000             500.00000
# mean          7.03014           26.586980  119.496000            4032.92694
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   farm_id               500 non-null    str
#  1   region_x              500 non-null    str
#  2   crop_type             500 non-null    str
#  3   soil_moisture_%       500 non-null    float64
#  4   soil_pH               500 non-null    float64
#  5   temperature_C         500 non-null    float64
#  6   rainfall_mm           500 non-null    float64
#  7   humidity_%            500 non-null    float64
#  8   sunlight_hours        500 non-null    float64
#  9   irrigation_type       350 non-null    str
#  10  fertilizer_type       500 non-null    str
#  11  pesticide_usage_ml    500 non-null    float64
#  12  sowing_date           500 non-null    str
#  13  harvest_date          500 non-null    str
#  14  total_days            500 non-null    int64
# ...

# %%
df.duplicated(subset='farm_id').sum()
# Out:
# np.int64(0)

# %%
df['irrigation_type'].unique()
# Out:
# <StringArray>
# [nan, 'Sprinkler', 'Drip', 'Manual']
# Length: 4, dtype: str

# %%
df["irrigation_type"].isnull().sum()
# Out:
# np.int64(150)

# %%
df["crop_disease_status"].unique()
# Out:
# <StringArray>
# ['Mild', nan, 'Severe', 'Moderate']
# Length: 4, dtype: str

# %%
df["crop_disease_status"].value_counts().sum()
# Out:
# np.int64(370)

# %%
df.duplicated(subset='sensor_id').sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['farm_id', 'region_x', 'crop_type', 'soil_moisture_%', 'soil_pH',
#        'temperature_C', 'rainfall_mm', 'humidity_%', 'sunlight_hours',
#        'irrigation_type', 'fertilizer_type', 'pesticide_usage_ml',
#        'sowing_date', 'harvest_date', 'total_days', 'yield_kg_per_hectare',
#        'sensor_id', 'timestamp', 'latitude', 'longitude', 'NDVI_index',
#        'crop_disease_status', 'date_join', 'region_maroc', 'et0',
#        'wind_speed_max', 'radiation_sum'],
#       dtype='str')

# %%
mild_crops = df[df['crop_disease_status'] == 'Mild']
severe_crops = df[df['crop_disease_status'] == 'Severe']
moderate_crops = df[df['crop_disease_status'] == 'Moderate']

# %%
mild_crops.describe()
# Out:
#        soil_moisture_%     soil_pH  temperature_C  rainfall_mm  humidity_%  \
# count       125.000000  125.000000     125.000000   125.000000  125.000000
# mean         26.454240    6.522480      24.645120   188.920000   66.027120
# std          10.248553    0.589433       5.343632    76.194344   14.762927
# min          10.340000    5.510000      15.040000    52.350000   40.640000
# 25%          17.740000    5.990000      20.400000   119.430000   53.030000
# 50%          25.810000    6.550000      24.480000   206.330000   68.870000
# 75%          35.650000    7.040000      29.530000   250.510000   77.590000
# max          44.980000    7.500000      34.520000   298.960000   90.000000
#
#        sunlight_hours  pesticide_usage_ml  total_days  yield_kg_per_hectare  \
# count      125.000000          125.000000  125.000000            125.000000
# mean         7.108640           26.859840  118.056000           4089.871760
# ...

# %%
severe_crops.describe()
# Out:
#        soil_moisture_%     soil_pH  temperature_C  rainfall_mm  humidity_%  \
# count       133.000000  133.000000     133.000000   133.000000  133.000000
# mean         27.717218    6.564662      24.769774   184.842707   64.854812
# std          10.086458    0.548856       5.778950    69.764717   14.806035
# min          10.160000    5.510000      15.000000    50.170000   40.290000
# 25%          18.750000    6.180000      19.850000   131.250000   51.280000
# 50%          28.190000    6.610000      24.780000   193.920000   64.680000
# 75%          36.260000    7.010000      29.200000   238.080000   78.410000
# max          44.690000    7.480000      34.710000   298.080000   89.740000
#
#        sunlight_hours  pesticide_usage_ml  total_days  yield_kg_per_hectare  \
# count      133.000000          133.000000  133.000000            133.000000
# mean         7.131353           26.680075  118.082707           4029.344286
# ...

# %%
severe_crops['crop_type'].unique()
# Out:
# <StringArray>
# ['Cotton', 'Rice', 'Maize', 'Soybean', 'Wheat']
# Length: 5, dtype: str

# %%
cotton_s = severe_crops[severe_crops["crop_type"] == 'Cotton']
cotton_s.drop(columns=['crop_type','crop_disease_status'],inplace=True)
cotton_s
# Out:
#       farm_id     region_x  soil_moisture_%  soil_pH  temperature_C  \
# 4    FARM0005  Central USA            19.37     5.92          33.86
# 24   FARM0025    South USA            18.54     6.81          15.11
# 26   FARM0027  Central USA            12.71     6.07          20.43
# 28   FARM0029  Central USA            35.35     7.18          33.39
# 32   FARM0033  South India            16.16     6.54          28.01
# 42   FARM0043  Central USA            38.47     6.60          24.10
# 44   FARM0045  South India            42.64     6.08          29.11
# 46   FARM0047  East Africa            18.17     7.05          15.87
# 103  FARM0104    South USA            32.77     7.01          20.74
# 108  FARM0109  East Africa            28.49     6.22          33.34
# 122  FARM0123  North India            23.27     6.61          16.12
# 125  FARM0126  Central USA            27.17     6.21          33.82
# 131  FARM0132  East Africa            28.70     7.35          32.39
# ...

# %%
mild_crops['crop_type'].unique()
# Out:
# <StringArray>
# ['Wheat', 'Maize', 'Soybean', 'Cotton', 'Rice']
# Length: 5, dtype: str

# %%
cotton_m = mild_crops[mild_crops["crop_type"] == 'Cotton']
cotton_m.drop(columns=['crop_type','crop_disease_status'],inplace=True)
cotton_m
# Out:
#       farm_id     region_x  soil_moisture_%  soil_pH  temperature_C  \
# 21   FARM0022  Central USA            12.45     6.83          21.60
# 29   FARM0030  Central USA            18.83     5.66          15.39
# 51   FARM0052  North India            19.61     6.63          28.72
# 110  FARM0111  North India            11.11     6.32          30.38
# 191  FARM0192  Central USA            33.16     6.82          20.40
# 206  FARM0207  North India            23.56     7.41          34.52
# 219  FARM0220  Central USA            17.82     7.04          29.66
# 253  FARM0254  East Africa            16.64     5.87          21.95
# 257  FARM0258  East Africa            16.63     6.55          19.98
# 259  FARM0260  Central USA            25.66     6.29          29.53
# 272  FARM0273  North India            14.69     7.19          24.38
# 277  FARM0278  East Africa            11.54     5.84          21.70
# 294  FARM0295  East Africa            14.00     6.69          21.51
# ...

# %%
cotton_m.describe()
# Out:
#        soil_moisture_%    soil_pH  temperature_C  rainfall_mm  humidity_%  \
# count        24.000000  24.000000      24.000000    24.000000   24.000000
# mean         23.100000   6.618333      24.180833   209.449583   65.807917
# std          10.643732   0.564767       5.454837    66.447771   16.600001
# min          11.110000   5.570000      15.210000    74.410000   41.370000
# 25%          14.840000   6.290000      21.045000   170.767500   49.135000
# 50%          18.470000   6.755000      22.740000   219.200000   65.425000
# 75%          31.592500   7.025000      29.562500   266.067500   82.317500
# max          43.860000   7.440000      34.520000   298.520000   90.000000
#
#        sunlight_hours  pesticide_usage_ml  total_days  yield_kg_per_hectare  \
# count       24.000000           24.000000   24.000000             24.000000
# mean         6.892083           25.364583  120.541667           4027.146667
# ...

# %%
cotton_s.describe()
# Out:
#        soil_moisture_%    soil_pH  temperature_C  rainfall_mm  humidity_%  \
# count        32.000000  32.000000      32.000000    32.000000   32.000000
# mean         26.395625   6.568125      24.701563   181.759687   60.046250
# std           9.332604   0.556512       6.396262    66.688167   15.670886
# min          10.160000   5.700000      15.110000    52.360000   40.290000
# 25%          19.027500   6.110000      18.985000   132.720000   45.927500
# 50%          26.460000   6.565000      23.785000   190.790000   55.945000
# 75%          33.190000   7.070000      30.567500   237.012500   75.970000
# max          44.180000   7.470000      34.440000   295.180000   85.980000
#
#        sunlight_hours  pesticide_usage_ml  total_days  yield_kg_per_hectare  \
# count       32.000000           32.000000   32.000000             32.000000
# mean         7.548437           27.021562  116.625000           3967.243125
# ...

# %%
df.head()
# Out:
#     farm_id     region_x crop_type  soil_moisture_%  soil_pH  temperature_C  \
# 0  FARM0001  North India     Wheat            35.95     5.99          17.79
# 1  FARM0002    South USA   Soybean            19.74     7.24          30.18
# 2  FARM0003    South USA     Wheat            29.32     7.16          27.37
# 3  FARM0004  Central USA     Maize            17.33     6.03          33.73
# 4  FARM0005  Central USA    Cotton            19.37     5.92          33.86
#
#    rainfall_mm  humidity_%  sunlight_hours irrigation_type  ...   timestamp  \
# 0        75.62       77.03            7.27             NaN  ...  2024-03-19
# 1        89.91       61.13            5.67       Sprinkler  ...  2024-04-21
# 2       265.43       68.87            8.23            Drip  ...  2024-02-28
# 3       212.01       70.46            5.03       Sprinkler  ...  2024-05-14
# 4       269.09       55.73            7.93             NaN  ...  2024-04-13
#
# ...

# %%
df.describe()
# Out:
#        soil_moisture_%     soil_pH  temperature_C  rainfall_mm  humidity_%  \
# count       500.000000  500.000000     500.000000   500.000000  500.000000
# mean         26.750140    6.523980      24.675740   181.685740   65.194460
# std          10.150053    0.585558       5.348899    72.293091   14.642849
# min          10.160000    5.510000      15.000000    50.170000   40.230000
# 25%          17.890000    6.030000      20.295000   119.217500   51.865000
# 50%          25.855000    6.530000      24.655000   191.545000   65.685000
# 75%          36.022500    7.040000      29.090000   239.035000   77.995000
# max          44.980000    7.500000      34.840000   298.960000   90.000000
#
#        sunlight_hours  pesticide_usage_ml  total_days  yield_kg_per_hectare  \
# count       500.00000          500.000000  500.000000             500.00000
# mean          7.03014           26.586980  119.496000            4032.92694
# ...

# %%
df['crop_disease_status'] = df['crop_disease_status'].fillna("unknown")

# %%
df['crop_disease_status'].unique()
# Out:
# <StringArray>
# ['Mild', 'unknown', 'Severe', 'Moderate']
# Length: 4, dtype: str

# %%
unknown = df[df['crop_disease_status'] == 'unknown']
unknown.describe()
# Out:
#        soil_moisture_%     soil_pH  temperature_C  rainfall_mm  humidity_%  \
# count       130.000000  130.000000     130.000000   130.000000  130.000000
# mean         26.618769    6.517231      24.723846   177.430846   65.281231
# std          10.002995    0.589458       5.086874    70.260362   15.203665
# min          10.220000    5.530000      15.250000    52.420000   40.420000
# 25%          17.797500    5.992500      20.520000   116.470000   51.145000
# 50%          25.170000    6.485000      24.850000   186.750000   68.125000
# 75%          35.937500    7.040000      28.715000   235.602500   77.660000
# max          44.910000    7.490000      33.950000   298.090000   88.820000
#
#        sunlight_hours  pesticide_usage_ml  total_days  yield_kg_per_hectare  \
# count      130.000000          130.000000  130.000000            130.000000
# mean         6.995231           26.433846  121.523077           4082.647615
# ...

# %%
# Out:
#          farm_id     region_x crop_type irrigation_type fertilizer_type  \
# count        130          130       130              95             130
# unique       130            5         5               3               3
# top     FARM0002  Central USA     Maize       Sprinkler         Organic
# freq           1           30        36              32              50
#
#        sowing_date harvest_date sensor_id   timestamp crop_disease_status  \
# count          130          130       130         130                 130
# unique          67           78       130          96                   1
# top     2024-02-14   2024-07-04  SENS0002  2024-04-14             unknown
# freq             6            5         1           4                 130
#
#          date_join region_maroc
# count          130          104
# unique          96            4
# top     2024-04-14  Saiss (Fes)
# freq             4           30
