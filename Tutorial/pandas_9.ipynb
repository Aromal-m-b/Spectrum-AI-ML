# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Dataset/Accident/Accident 2014.csv')

# %%
df.head()
# Out:
#   Reference Number  Grid Ref: Easting  Grid Ref: Northing  Number of Vehicles  \
# 0          11S0281             407491              428929                   1
# 1          11S1147             412912              429039                   1
# 2          11S1147             412912              429039                   1
# 3          11U0285             407179              424776                   2
# 4          11U0285             407179              424776                   2
#
#   Accident Date  Time (24hr)  1st Road Class 1st Road Class & No  \
# 0    28/01/2014          835               6                   U
# 1    28/01/2014         1745               6                   U
# 2    28/01/2014         1745               6                   U
# 3    30/01/2014          900               6                   U
# 4    30/01/2014          900               6                   U
#
#    Road Surface  Lighting Conditions  Weather Conditions Local Authority  \
# ...

# %%
column_names = df.columns.to_list()

# %%
type(column_names)
# Out:
# list

# %%
df[column_names[0]].nunique()
# Out:
# 427

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 623 entries, 0 to 622
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Reference Number     623 non-null    str
#  1   Grid Ref: Easting    623 non-null    int64
#  2   Grid Ref: Northing   623 non-null    int64
#  3   Number of Vehicles   623 non-null    int64
#  4   Accident Date        623 non-null    str
#  5   Time (24hr)          623 non-null    int64
#  6   1st Road Class       623 non-null    int64
#  7   1st Road Class & No  623 non-null    str
#  8   Road Surface         623 non-null    int64
#  9   Lighting Conditions  623 non-null    int64
#  10  Weather Conditions   623 non-null    int64
#  11  Local Authority      623 non-null    str
#  12  Casualty Class       623 non-null    int64
#  13  Casualty Severity    623 non-null    int64
#  14  Sex of Casualty      623 non-null    int64
#  15  Age of Casualty      623 non-null    int64
# ...

# %%
df.drop_duplicates(inplace= True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
pd.crosstab(df['Reference Number'],df['Grid Ref: Easting'])
# Out:
# Grid Ref: Easting  389828  390043  392729  392964  392993  393060  393120  \
# Reference Number
# 1.90E+243               0       0       0       0       0       0       0
# 11S0281                 0       0       0       0       0       0       0
# 11S1147                 0       0       0       0       0       0       0
# 11U0285                 0       0       0       0       0       0       0
# 11U1201                 0       0       0       0       0       0       0
# ...                   ...     ...     ...     ...     ...     ...     ...
# 1CQ1464                 0       0       0       0       0       0       0
# 1CT0204                 0       0       0       0       0       0       0
# 1CU0561                 0       0       0       0       0       0       0
# 1CU0803                 0       0       0       0       0       0       0
# 1CV0997                 0       0       0       0       0       0       0
#
# ...
